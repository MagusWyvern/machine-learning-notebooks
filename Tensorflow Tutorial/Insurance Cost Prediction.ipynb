# %%
import pandas as pd

# %% [markdown]
# In this example, we are going to predict the insurance charges using age, gender, body-mass-index(BMI), number of children, smoker status and region.
#
# Dataset info: https://www.kaggle.com/mirichoi0218/insurance
#
# # Read CSV
#
# Let us start by reading the CSV file using `pandas.read_csv`

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv')

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Data Preparation

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# The data type for 'sex', 'smoker', and 'region' a 'object' Dtype . Use `pd.Categorical` to convert them into 'category' Dtype

# %%
dataset['sex'] = pd.Categorical(dataset['sex'])
dataset['smoker'] = pd.Categorical(dataset['smoker'])
dataset['region'] = pd.Categorical(dataset['region'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   category
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   category
#  5   region    1338 non-null   category
#  6   charges   1338 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 46.2 KB

# %% [markdown]
# Before we start to build model, let's do some data preprocessing:
# - Convert all categorical columns into numerical representation
# - Split dataset into a train set and a test set
# - Normalize data

# %%
dataset['sex'] = dataset['sex'].cat.codes
dataset['smoker'] = dataset['smoker'].cat.codes
dataset['region'] = dataset['region'].cat.codes

# %%
dataset.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# `dataset.pop()` removes "charges" column from dataset and stores it in a variable called 'target'

# %%
target = dataset.pop('charges')
features = dataset

# %%
target.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
features.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    0  27.900         0       1       3
# 1   18    1  33.770         1       0       2
# 2   28    1  33.000         3       0       2
# 3   33    1  22.705         0       0       1
# 4   32    1  28.880         0       0       1

# %% [markdown]
# # Create Train and Test Set
#
# The original dataset is split for evaluation purpose. We will use the train set for model training, and use the test set to evaluate our model. By evaluation, we mean to assess how well the model can generalize to new, unseen data.
# We will be using the `train_test_split()` function provided by sklearn to split the data into train and test set.

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(features, target, test_size=0.2, random_state=123)

# %%
train_X.shape, test_X.shape, train_y.shape, test_y.shape
# Out:
# ((1070, 6), (268, 6), (1070,), (268,))

# %% [markdown]
# Next, we will perform data normalization. The goal of normalization is to change the values of every numeric columns in the dataset to a common scale, without distorting the differences in terms of range of values. Data normalization generally speeds up learning and leads to faster convergence.

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()

scaler.fit(train_X)

train_X_scaled = scaler.transform(train_X)
test_X_scaled = scaler.transform(test_X)

# %% [markdown]
# # Create Input Pipelines

# %% [markdown]
# `tf.data.Dataset` is the function provided by Tensorflow to create input pipelines.

# %%
import tensorflow as tf

train_dataset = tf.data.Dataset.from_tensor_slices((train_X_scaled, train_y))
test_dataset = tf.data.Dataset.from_tensor_slices((test_X_scaled, test_y))

# %%
for feat, targ in train_dataset.take(5):
    print ('Features: {}, Target: {}'.format(feat, targ))
# Out:
# Features: [ 0.06207177  0.98884723 -0.71961    -0.06736631 -0.5        -0.46038891], Target: 6389.37785
# Features: [-0.15057538 -1.01127855  1.28697921 -0.8864794   2.          0.45695957], Target: 40419.0191
# Features: [ 0.77089561  0.98884723 -0.67224951 -0.8864794  -0.5         1.37430805], Target: 8444.474
# Features: [ 0.48736607  0.98884723 -0.97219929  1.57085987 -0.5        -1.37773739], Target: 9500.57305
# Features: [-1.28469352 -1.01127855 -2.20107939 -0.06736631 -0.5         1.37430805], Target: 2585.269

# %% [markdown]
# Shuffle the train set and subsequently create batches of samples

# %%
train_dataset_batch = train_dataset.shuffle(buffer_size=100).batch(8)
test_dataset_batch = test_dataset.batch(8)

# %%
features, targets = next(iter(train_dataset_batch))
print('Features shape: {}, targets shape: {}'.format(features.numpy().shape, targets.numpy().shape))
# Out:
# Features shape: (8, 6), targets shape: (8,)

# %% [markdown]
# # Model training

# %% [markdown]
# In Keras, we can define the layers we desired and stack them using the `tf.keras.Sequential()` function. In this case, our feature size is six, so correspondingly we create six nodes in the first layer to receive input for our features. The input layer is followed by one hidden layer with the size of ten nodes, and an output layer with the size of one node to output a prediction.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(6, activation='relu', dtype='float64'),
    tf.keras.layers.Dense(10, activation='relu', dtype='float64'),
    tf.keras.layers.Dense(1, dtype='float64')
])

# %% [markdown]
# After the model is defined, we have to define the configurations required to carry out model training such as optimizer, loss function, and evaluation metrics. We can do that by calling the `.compile()` function and specify our desired optimizer, loss function and evaluation metrics

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.mean_absolute_percentage_error]
)

# %% [markdown]
# Now, we begin to train the model using the `.fit()` function, by supplying the train set dataloader and training iteration. The parameter `validation_data` is optional, but here we assign a test dataloader to it, so that once it finishes training, it will proceed to evaluate the given test set at the end of each epoch.

# %%
model.fit(
    train_dataset_batch, 
    epochs=150, 
    validation_data=test_dataset_batch
)
# Out:
# Epoch 1/150
# 134/134 [==============================] - 1s 3ms/step - loss: 318859136.0000 - mean_absolute_percentage_error: 99.9911 - val_loss: 337663936.0000 - val_mean_absolute_percentage_error: 99.9833
# Epoch 2/150
# 134/134 [==============================] - 0s 2ms/step - loss: 318803264.0000 - mean_absolute_percentage_error: 99.9674 - val_loss: 337576352.0000 - val_mean_absolute_percentage_error: 99.9504
# Epoch 3/150
# 134/134 [==============================] - 0s 1ms/step - loss: 318660320.0000 - mean_absolute_percentage_error: 99.9113 - val_loss: 337325728.0000 - val_mean_absolute_percentage_error: 99.8669
# Epoch 4/150
# 134/134 [==============================] - 0s 1ms/step - loss: 318273536.0000 - mean_absolute_percentage_error: 99.7819 - val_loss: 336727264.0000 - val_mean_absolute_percentage_error: 99.6983
# Epoch 5/150
# 134/134 [==============================] - 0s 2ms/step - loss: 317511552.0000 - mean_absolute_percentage_error: 99.5605 - val_loss: 335657408.0000 - val_mean_absolute_percentage_error: 99.4293
# Epoch 6/150
# 134/134 [==============================] - 0s 1ms/step - loss: 316253632.0000 - mean_absolute_percentage_error: 99.2332 - val_loss: 333993344.0000 - val_mean_absolute_percentage_error: 99.0407
# Epoch 7/150
# 134/134 [==============================] - 0s 2ms/step - loss: 314412864.0000 - mean_absolute_percentage_error: 98.7838 - val_loss: 331676544.0000 - val_mean_absolute_percentage_error: 98.5244
# Epoch 8/150
# 134/134 [==============================] - 0s 2ms/step - loss: 311932288.0000 - mean_absolute_percentage_error: 98.2085 - val_loss: 328687168.0000 - val_mean_absolute_percentage_error: 97.8818
# Epoch 9/150
# 134/134 [==============================] - 0s 2ms/step - loss: 308803520.0000 - mean_absolute_percentage_error: 97.5005 - val_loss: 324991040.0000 - val_mean_absolute_percentage_error: 97.1061
# Epoch 10/150
# 134/134 [==============================] - 0s 2ms/step - loss: 305020192.0000 - mean_absolute_percentage_error: 96.6648 - val_loss: 320530784.0000 - val_mean_absolute_percentage_error: 96.1847
# Epoch 11/150
# 134/134 [==============================] - 0s 2ms/step - loss: 300528736.0000 - mean_absolute_percentage_error: 95.6953 - val_loss: 315306400.0000 - val_mean_absolute_percentage_error: 95.1202
# Epoch 12/150
# 134/134 [==============================] - 0s 2ms/step - loss: 295310464.0000 - mean_absolute_percentage_error: 94.5713 - val_loss: 309234080.0000 - val_mean_absolute_percentage_error: 93.8996
# Epoch 13/150
# 134/134 [==============================] - 0s 2ms/step - loss: 289390464.0000 - mean_absolute_percentage_error: 93.3136 - val_loss: 302506624.0000 - val_mean_absolute_percentage_error: 92.5348
# Epoch 14/150
# 134/134 [==============================] - 0s 2ms/step - loss: 282753216.0000 - mean_absolute_percentage_error: 91.9008 - val_loss: 295007776.0000 - val_mean_absolute_percentage_error: 91.0162
# Epoch 15/150
# 134/134 [==============================] - 0s 2ms/step - loss: 275434016.0000 - mean_absolute_percentage_error: 90.3370 - val_loss: 286753216.0000 - val_mean_absolute_percentage_error: 89.3358
# Epoch 16/150
# 134/134 [==============================] - 0s 1ms/step - loss: 267538288.0000 - mean_absolute_percentage_error: 88.6445 - val_loss: 277906944.0000 - val_mean_absolute_percentage_error: 87.5039
# Epoch 17/150
# 134/134 [==============================] - 0s 2ms/step - loss: 259067424.0000 - mean_absolute_percentage_error: 86.8437 - val_loss: 268578240.0000 - val_mean_absolute_percentage_error: 85.5524
# Epoch 18/150
# 134/134 [==============================] - 0s 1ms/step - loss: 250124272.0000 - mean_absolute_percentage_error: 84.8850 - val_loss: 258480960.0000 - val_mean_absolute_percentage_error: 83.4177
# Epoch 19/150
# 134/134 [==============================] - 0s 2ms/step - loss: 240696496.0000 - mean_absolute_percentage_error: 82.8407 - val_loss: 248059744.0000 - val_mean_absolute_percentage_error: 81.1638
# Epoch 20/150
# 134/134 [==============================] - 0s 1ms/step - loss: 230910960.0000 - mean_absolute_percentage_error: 80.6966 - val_loss: 237414464.0000 - val_mean_absolute_percentage_error: 78.8033
# Epoch 21/150
# 134/134 [==============================] - 0s 1ms/step - loss: 220753392.0000 - mean_absolute_percentage_error: 78.4288 - val_loss: 226182992.0000 - val_mean_absolute_percentage_error: 76.3475
# Epoch 22/150
# 134/134 [==============================] - 0s 1ms/step - loss: 210380352.0000 - mean_absolute_percentage_error: 76.0821 - val_loss: 214972352.0000 - val_mean_absolute_percentage_error: 73.8236
# Epoch 23/150
# 134/134 [==============================] - 0s 1ms/step - loss: 199855616.0000 - mean_absolute_percentage_error: 73.6667 - val_loss: 203432512.0000 - val_mean_absolute_percentage_error: 71.1617
# Epoch 24/150
# 134/134 [==============================] - 0s 2ms/step - loss: 189263152.0000 - mean_absolute_percentage_error: 71.2027 - val_loss: 191821216.0000 - val_mean_absolute_percentage_error: 68.4604
# Epoch 25/150
# 134/134 [==============================] - 0s 1ms/step - loss: 178626416.0000 - mean_absolute_percentage_error: 68.6724 - val_loss: 180300288.0000 - val_mean_absolute_percentage_error: 65.8312
# Epoch 26/150
# 134/134 [==============================] - 0s 2ms/step - loss: 168065168.0000 - mean_absolute_percentage_error: 66.1611 - val_loss: 169000864.0000 - val_mean_absolute_percentage_error: 63.1793
# Epoch 27/150
# 134/134 [==============================] - 0s 1ms/step - loss: 157673680.0000 - mean_absolute_percentage_error: 63.6377 - val_loss: 157747824.0000 - val_mean_absolute_percentage_error: 60.6310
# Epoch 28/150
# 134/134 [==============================] - 0s 2ms/step - loss: 147537008.0000 - mean_absolute_percentage_error: 61.1361 - val_loss: 146775936.0000 - val_mean_absolute_percentage_error: 58.1825
# Epoch 29/150
# 134/134 [==============================] - 0s 2ms/step - loss: 137646208.0000 - mean_absolute_percentage_error: 58.7516 - val_loss: 136382976.0000 - val_mean_absolute_percentage_error: 55.8358
# Epoch 30/150
# 134/134 [==============================] - 0s 2ms/step - loss: 128132592.0000 - mean_absolute_percentage_error: 56.4834 - val_loss: 126130496.0000 - val_mean_absolute_percentage_error: 53.5525
# Epoch 31/150
# 134/134 [==============================] - 0s 2ms/step - loss: 119035000.0000 - mean_absolute_percentage_error: 54.3829 - val_loss: 116518824.0000 - val_mean_absolute_percentage_error: 51.4996
# Epoch 32/150
# 134/134 [==============================] - 0s 2ms/step - loss: 110429648.0000 - mean_absolute_percentage_error: 52.4934 - val_loss: 107138576.0000 - val_mean_absolute_percentage_error: 49.7371
# Epoch 33/150
# 134/134 [==============================] - 0s 2ms/step - loss: 102306144.0000 - mean_absolute_percentage_error: 50.7937 - val_loss: 98588352.0000 - val_mean_absolute_percentage_error: 48.1677
# Epoch 34/150
# 134/134 [==============================] - 0s 2ms/step - loss: 94745912.0000 - mean_absolute_percentage_error: 49.3646 - val_loss: 90587200.0000 - val_mean_absolute_percentage_error: 46.7053
# Epoch 35/150
# 134/134 [==============================] - 0s 2ms/step - loss: 87720720.0000 - mean_absolute_percentage_error: 48.1511 - val_loss: 83187792.0000 - val_mean_absolute_percentage_error: 45.4332
# Epoch 36/150
# 134/134 [==============================] - 0s 2ms/step - loss: 81292792.0000 - mean_absolute_percentage_error: 47.0586 - val_loss: 76408984.0000 - val_mean_absolute_percentage_error: 44.3745
# Epoch 37/150
# 134/134 [==============================] - 0s 2ms/step - loss: 75467584.0000 - mean_absolute_percentage_error: 46.1232 - val_loss: 70283320.0000 - val_mean_absolute_percentage_error: 43.4870
# Epoch 38/150
# 134/134 [==============================] - 0s 2ms/step - loss: 70231656.0000 - mean_absolute_percentage_error: 45.3189 - val_loss: 64808180.0000 - val_mean_absolute_percentage_error: 42.7766
# Epoch 39/150
# 134/134 [==============================] - 0s 1ms/step - loss: 65575756.0000 - mean_absolute_percentage_error: 44.6576 - val_loss: 59917384.0000 - val_mean_absolute_percentage_error: 42.2640
# Epoch 40/150
# 134/134 [==============================] - 0s 1ms/step - loss: 61470588.0000 - mean_absolute_percentage_error: 44.1863 - val_loss: 55550036.0000 - val_mean_absolute_percentage_error: 41.9954
# Epoch 41/150
# 134/134 [==============================] - 0s 2ms/step - loss: 57877156.0000 - mean_absolute_percentage_error: 43.9217 - val_loss: 51697028.0000 - val_mean_absolute_percentage_error: 41.8306
# Epoch 42/150
# 134/134 [==============================] - 0s 2ms/step - loss: 54772576.0000 - mean_absolute_percentage_error: 43.7061 - val_loss: 48537864.0000 - val_mean_absolute_percentage_error: 41.7151
# Epoch 43/150
# 134/134 [==============================] - 0s 2ms/step - loss: 52129492.0000 - mean_absolute_percentage_error: 43.5937 - val_loss: 45661820.0000 - val_mean_absolute_percentage_error: 41.7463
# Epoch 44/150
# 134/134 [==============================] - 0s 2ms/step - loss: 49889772.0000 - mean_absolute_percentage_error: 43.5547 - val_loss: 43246976.0000 - val_mean_absolute_percentage_error: 41.7356
# Epoch 45/150
# 134/134 [==============================] - 0s 2ms/step - loss: 47999952.0000 - mean_absolute_percentage_error: 43.5218 - val_loss: 41253012.0000 - val_mean_absolute_percentage_error: 41.7051
# Epoch 46/150
# 134/134 [==============================] - 0s 2ms/step - loss: 46406660.0000 - mean_absolute_percentage_error: 43.5110 - val_loss: 39492868.0000 - val_mean_absolute_percentage_error: 41.6945
# Epoch 47/150
# 134/134 [==============================] - 0s 2ms/step - loss: 45077036.0000 - mean_absolute_percentage_error: 43.5082 - val_loss: 38025128.0000 - val_mean_absolute_percentage_error: 41.6787
# Epoch 48/150
# 134/134 [==============================] - 0s 2ms/step - loss: 43959412.0000 - mean_absolute_percentage_error: 43.4532 - val_loss: 36818388.0000 - val_mean_absolute_percentage_error: 41.5362
# Epoch 49/150
# 134/134 [==============================] - 0s 1ms/step - loss: 43029308.0000 - mean_absolute_percentage_error: 43.3578 - val_loss: 35734408.0000 - val_mean_absolute_percentage_error: 41.4914
# Epoch 50/150
# 134/134 [==============================] - 0s 1ms/step - loss: 42258376.0000 - mean_absolute_percentage_error: 43.2201 - val_loss: 34840040.0000 - val_mean_absolute_percentage_error: 41.3704
# Epoch 51/150
# 134/134 [==============================] - 0s 2ms/step - loss: 41607016.0000 - mean_absolute_percentage_error: 42.9964 - val_loss: 34089288.0000 - val_mean_absolute_percentage_error: 41.1865
# Epoch 52/150
# 134/134 [==============================] - 0s 2ms/step - loss: 41058864.0000 - mean_absolute_percentage_error: 42.7956 - val_loss: 33454524.0000 - val_mean_absolute_percentage_error: 41.0018
# Epoch 53/150
# 134/134 [==============================] - 0s 1ms/step - loss: 40589084.0000 - mean_absolute_percentage_error: 42.5518 - val_loss: 32884404.0000 - val_mean_absolute_percentage_error: 40.7724
# Epoch 54/150
# 134/134 [==============================] - 0s 2ms/step - loss: 40178660.0000 - mean_absolute_percentage_error: 42.3056 - val_loss: 32376022.0000 - val_mean_absolute_percentage_error: 40.5757
# Epoch 55/150
# 134/134 [==============================] - 0s 2ms/step - loss: 39821308.0000 - mean_absolute_percentage_error: 42.0092 - val_loss: 31962786.0000 - val_mean_absolute_percentage_error: 40.3315
# Epoch 56/150
# 134/134 [==============================] - 0s 2ms/step - loss: 39516484.0000 - mean_absolute_percentage_error: 41.7257 - val_loss: 31564242.0000 - val_mean_absolute_percentage_error: 40.0538
# Epoch 57/150
# 134/134 [==============================] - 0s 2ms/step - loss: 39230832.0000 - mean_absolute_percentage_error: 41.3737 - val_loss: 31246820.0000 - val_mean_absolute_percentage_error: 39.7555
# Epoch 58/150
# 134/134 [==============================] - 0s 1ms/step - loss: 38991468.0000 - mean_absolute_percentage_error: 41.0900 - val_loss: 30960474.0000 - val_mean_absolute_percentage_error: 39.5687
# Epoch 59/150
# 134/134 [==============================] - 0s 1ms/step - loss: 38778804.0000 - mean_absolute_percentage_error: 40.7812 - val_loss: 30704642.0000 - val_mean_absolute_percentage_error: 39.3028
# Epoch 60/150
# 134/134 [==============================] - 0s 2ms/step - loss: 38584048.0000 - mean_absolute_percentage_error: 40.4275 - val_loss: 30492694.0000 - val_mean_absolute_percentage_error: 38.9442
# Epoch 61/150
# 134/134 [==============================] - 0s 2ms/step - loss: 38416064.0000 - mean_absolute_percentage_error: 40.1506 - val_loss: 30275058.0000 - val_mean_absolute_percentage_error: 38.6857
# Epoch 62/150
# 134/134 [==============================] - 0s 1ms/step - loss: 38254460.0000 - mean_absolute_percentage_error: 39.8171 - val_loss: 30106934.0000 - val_mean_absolute_percentage_error: 38.3863
# Epoch 63/150
# 134/134 [==============================] - 0s 2ms/step - loss: 38127160.0000 - mean_absolute_percentage_error: 39.5960 - val_loss: 29958664.0000 - val_mean_absolute_percentage_error: 38.1645
# Epoch 64/150
# 134/134 [==============================] - 0s 1ms/step - loss: 38007804.0000 - mean_absolute_percentage_error: 39.3095 - val_loss: 29813624.0000 - val_mean_absolute_percentage_error: 37.9440
# Epoch 65/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37901684.0000 - mean_absolute_percentage_error: 39.0535 - val_loss: 29692782.0000 - val_mean_absolute_percentage_error: 37.6702
# Epoch 66/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37803052.0000 - mean_absolute_percentage_error: 38.8056 - val_loss: 29581548.0000 - val_mean_absolute_percentage_error: 37.5510
# Epoch 67/150
# 134/134 [==============================] - 0s 1ms/step - loss: 37726748.0000 - mean_absolute_percentage_error: 38.5995 - val_loss: 29489282.0000 - val_mean_absolute_percentage_error: 37.4038
# Epoch 68/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37641844.0000 - mean_absolute_percentage_error: 38.3584 - val_loss: 29414970.0000 - val_mean_absolute_percentage_error: 37.2220
# Epoch 69/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37573576.0000 - mean_absolute_percentage_error: 38.1816 - val_loss: 29339180.0000 - val_mean_absolute_percentage_error: 37.0355
# Epoch 70/150
# 134/134 [==============================] - 0s 1ms/step - loss: 37512448.0000 - mean_absolute_percentage_error: 37.9724 - val_loss: 29270136.0000 - val_mean_absolute_percentage_error: 36.9271
# Epoch 71/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37456652.0000 - mean_absolute_percentage_error: 37.8175 - val_loss: 29208636.0000 - val_mean_absolute_percentage_error: 36.8083
# Epoch 72/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37411804.0000 - mean_absolute_percentage_error: 37.6810 - val_loss: 29151226.0000 - val_mean_absolute_percentage_error: 36.6429
# Epoch 73/150
# 134/134 [==============================] - 0s 1ms/step - loss: 37366860.0000 - mean_absolute_percentage_error: 37.5565 - val_loss: 29112724.0000 - val_mean_absolute_percentage_error: 36.5253
# Epoch 74/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37323412.0000 - mean_absolute_percentage_error: 37.4473 - val_loss: 29053552.0000 - val_mean_absolute_percentage_error: 36.4175
# Epoch 75/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37276272.0000 - mean_absolute_percentage_error: 37.3793 - val_loss: 29027700.0000 - val_mean_absolute_percentage_error: 36.2984
# Epoch 76/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37242160.0000 - mean_absolute_percentage_error: 37.2541 - val_loss: 28997562.0000 - val_mean_absolute_percentage_error: 36.2317
# Epoch 77/150
# 134/134 [==============================] - 0s 1ms/step - loss: 37196924.0000 - mean_absolute_percentage_error: 37.1716 - val_loss: 28952284.0000 - val_mean_absolute_percentage_error: 36.0979
# Epoch 78/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37171156.0000 - mean_absolute_percentage_error: 37.1478 - val_loss: 28924560.0000 - val_mean_absolute_percentage_error: 36.0255
# Epoch 79/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37139620.0000 - mean_absolute_percentage_error: 37.1188 - val_loss: 28900904.0000 - val_mean_absolute_percentage_error: 35.9300
# Epoch 80/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37110988.0000 - mean_absolute_percentage_error: 37.1138 - val_loss: 28873410.0000 - val_mean_absolute_percentage_error: 35.9620
# Epoch 81/150
# 134/134 [==============================] - 0s 1ms/step - loss: 37087104.0000 - mean_absolute_percentage_error: 37.0827 - val_loss: 28842392.0000 - val_mean_absolute_percentage_error: 35.9103
# Epoch 82/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37064304.0000 - mean_absolute_percentage_error: 37.1192 - val_loss: 28823970.0000 - val_mean_absolute_percentage_error: 35.7917
# Epoch 83/150
# 134/134 [==============================] - 0s 1ms/step - loss: 37036628.0000 - mean_absolute_percentage_error: 37.0734 - val_loss: 28810530.0000 - val_mean_absolute_percentage_error: 35.7967
# Epoch 84/150
# 134/134 [==============================] - 0s 2ms/step - loss: 37015560.0000 - mean_absolute_percentage_error: 37.1041 - val_loss: 28793724.0000 - val_mean_absolute_percentage_error: 35.8015
# Epoch 85/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36998872.0000 - mean_absolute_percentage_error: 37.1625 - val_loss: 28777982.0000 - val_mean_absolute_percentage_error: 35.7433
# Epoch 86/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36978456.0000 - mean_absolute_percentage_error: 37.1264 - val_loss: 28758726.0000 - val_mean_absolute_percentage_error: 35.7942
# Epoch 87/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36966404.0000 - mean_absolute_percentage_error: 37.1866 - val_loss: 28736282.0000 - val_mean_absolute_percentage_error: 35.7612
# Epoch 88/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36947856.0000 - mean_absolute_percentage_error: 37.1379 - val_loss: 28721382.0000 - val_mean_absolute_percentage_error: 35.7366
# Epoch 89/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36933920.0000 - mean_absolute_percentage_error: 37.1595 - val_loss: 28711334.0000 - val_mean_absolute_percentage_error: 35.7380
# Epoch 90/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36913192.0000 - mean_absolute_percentage_error: 37.1578 - val_loss: 28696634.0000 - val_mean_absolute_percentage_error: 35.6826
# Epoch 91/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36893212.0000 - mean_absolute_percentage_error: 37.2319 - val_loss: 28688296.0000 - val_mean_absolute_percentage_error: 35.7587
# Epoch 92/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36885484.0000 - mean_absolute_percentage_error: 37.2243 - val_loss: 28672452.0000 - val_mean_absolute_percentage_error: 35.7146
# Epoch 93/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36873572.0000 - mean_absolute_percentage_error: 37.2154 - val_loss: 28657618.0000 - val_mean_absolute_percentage_error: 35.7393
# Epoch 94/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36856428.0000 - mean_absolute_percentage_error: 37.3050 - val_loss: 28643502.0000 - val_mean_absolute_percentage_error: 35.7775
# Epoch 95/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36840288.0000 - mean_absolute_percentage_error: 37.2879 - val_loss: 28640806.0000 - val_mean_absolute_percentage_error: 35.7335
# Epoch 96/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36820880.0000 - mean_absolute_percentage_error: 37.3590 - val_loss: 28626526.0000 - val_mean_absolute_percentage_error: 35.7796
# Epoch 97/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36810476.0000 - mean_absolute_percentage_error: 37.3108 - val_loss: 28608418.0000 - val_mean_absolute_percentage_error: 35.7656
# Epoch 98/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36800240.0000 - mean_absolute_percentage_error: 37.3765 - val_loss: 28592870.0000 - val_mean_absolute_percentage_error: 35.8553
# Epoch 99/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36786364.0000 - mean_absolute_percentage_error: 37.3496 - val_loss: 28581296.0000 - val_mean_absolute_percentage_error: 35.7868
# Epoch 100/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36776552.0000 - mean_absolute_percentage_error: 37.3688 - val_loss: 28574712.0000 - val_mean_absolute_percentage_error: 35.7906
# Epoch 101/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36759128.0000 - mean_absolute_percentage_error: 37.3831 - val_loss: 28564270.0000 - val_mean_absolute_percentage_error: 35.8234
# Epoch 102/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36742568.0000 - mean_absolute_percentage_error: 37.3631 - val_loss: 28558104.0000 - val_mean_absolute_percentage_error: 35.7506
# Epoch 103/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36733652.0000 - mean_absolute_percentage_error: 37.4362 - val_loss: 28540196.0000 - val_mean_absolute_percentage_error: 35.8212
# Epoch 104/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36721292.0000 - mean_absolute_percentage_error: 37.4347 - val_loss: 28536264.0000 - val_mean_absolute_percentage_error: 35.7458
# Epoch 105/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36708636.0000 - mean_absolute_percentage_error: 37.4481 - val_loss: 28517510.0000 - val_mean_absolute_percentage_error: 35.8106
# Epoch 106/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36700236.0000 - mean_absolute_percentage_error: 37.4684 - val_loss: 28510998.0000 - val_mean_absolute_percentage_error: 35.7777
# Epoch 107/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36683732.0000 - mean_absolute_percentage_error: 37.5033 - val_loss: 28504672.0000 - val_mean_absolute_percentage_error: 35.7885
# Epoch 108/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36677928.0000 - mean_absolute_percentage_error: 37.5412 - val_loss: 28492452.0000 - val_mean_absolute_percentage_error: 35.8380
# Epoch 109/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36662636.0000 - mean_absolute_percentage_error: 37.4986 - val_loss: 28480234.0000 - val_mean_absolute_percentage_error: 35.8121
# Epoch 110/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36651564.0000 - mean_absolute_percentage_error: 37.5141 - val_loss: 28466390.0000 - val_mean_absolute_percentage_error: 35.8162
# Epoch 111/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36638592.0000 - mean_absolute_percentage_error: 37.5120 - val_loss: 28454004.0000 - val_mean_absolute_percentage_error: 35.8416
# Epoch 112/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36627612.0000 - mean_absolute_percentage_error: 37.5623 - val_loss: 28446398.0000 - val_mean_absolute_percentage_error: 35.8498
# Epoch 113/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36613296.0000 - mean_absolute_percentage_error: 37.5681 - val_loss: 28433054.0000 - val_mean_absolute_percentage_error: 35.8711
# Epoch 114/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36607920.0000 - mean_absolute_percentage_error: 37.5875 - val_loss: 28426324.0000 - val_mean_absolute_percentage_error: 35.8641
# Epoch 115/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36599500.0000 - mean_absolute_percentage_error: 37.5706 - val_loss: 28415798.0000 - val_mean_absolute_percentage_error: 35.8045
# Epoch 116/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36592884.0000 - mean_absolute_percentage_error: 37.5342 - val_loss: 28396898.0000 - val_mean_absolute_percentage_error: 35.8972
# Epoch 117/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36575744.0000 - mean_absolute_percentage_error: 37.5783 - val_loss: 28384110.0000 - val_mean_absolute_percentage_error: 35.8528
# Epoch 118/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36560028.0000 - mean_absolute_percentage_error: 37.5895 - val_loss: 28376882.0000 - val_mean_absolute_percentage_error: 35.8663
# Epoch 119/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36552948.0000 - mean_absolute_percentage_error: 37.5619 - val_loss: 28354278.0000 - val_mean_absolute_percentage_error: 35.8750
# Epoch 120/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36532248.0000 - mean_absolute_percentage_error: 37.5863 - val_loss: 28341844.0000 - val_mean_absolute_percentage_error: 35.8672
# Epoch 121/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36534016.0000 - mean_absolute_percentage_error: 37.5877 - val_loss: 28346130.0000 - val_mean_absolute_percentage_error: 35.7602
# Epoch 122/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36512136.0000 - mean_absolute_percentage_error: 37.5822 - val_loss: 28321484.0000 - val_mean_absolute_percentage_error: 35.8462
# Epoch 123/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36504924.0000 - mean_absolute_percentage_error: 37.6312 - val_loss: 28310068.0000 - val_mean_absolute_percentage_error: 35.9003
# Epoch 124/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36489460.0000 - mean_absolute_percentage_error: 37.6342 - val_loss: 28303466.0000 - val_mean_absolute_percentage_error: 35.8633
# Epoch 125/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36484452.0000 - mean_absolute_percentage_error: 37.6468 - val_loss: 28287568.0000 - val_mean_absolute_percentage_error: 35.8828
# Epoch 126/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36476532.0000 - mean_absolute_percentage_error: 37.6502 - val_loss: 28282350.0000 - val_mean_absolute_percentage_error: 35.8665
# Epoch 127/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36464240.0000 - mean_absolute_percentage_error: 37.6311 - val_loss: 28267386.0000 - val_mean_absolute_percentage_error: 35.8205
# Epoch 128/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36450120.0000 - mean_absolute_percentage_error: 37.6471 - val_loss: 28249212.0000 - val_mean_absolute_percentage_error: 35.9365
# Epoch 129/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36442756.0000 - mean_absolute_percentage_error: 37.6582 - val_loss: 28239874.0000 - val_mean_absolute_percentage_error: 35.8948
# Epoch 130/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36431172.0000 - mean_absolute_percentage_error: 37.7292 - val_loss: 28225600.0000 - val_mean_absolute_percentage_error: 35.8975
# Epoch 131/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36425436.0000 - mean_absolute_percentage_error: 37.7226 - val_loss: 28213200.0000 - val_mean_absolute_percentage_error: 35.9277
# Epoch 132/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36413696.0000 - mean_absolute_percentage_error: 37.6942 - val_loss: 28211336.0000 - val_mean_absolute_percentage_error: 35.8992
# Epoch 133/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36394696.0000 - mean_absolute_percentage_error: 37.6957 - val_loss: 28187470.0000 - val_mean_absolute_percentage_error: 35.7771
# Epoch 134/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36383012.0000 - mean_absolute_percentage_error: 37.6914 - val_loss: 28178154.0000 - val_mean_absolute_percentage_error: 35.8417
# Epoch 135/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36380532.0000 - mean_absolute_percentage_error: 37.7048 - val_loss: 28169082.0000 - val_mean_absolute_percentage_error: 35.8191
# Epoch 136/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36369944.0000 - mean_absolute_percentage_error: 37.7257 - val_loss: 28151224.0000 - val_mean_absolute_percentage_error: 35.8672
# Epoch 137/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36362284.0000 - mean_absolute_percentage_error: 37.7283 - val_loss: 28135802.0000 - val_mean_absolute_percentage_error: 35.8831
# Epoch 138/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36349324.0000 - mean_absolute_percentage_error: 37.7354 - val_loss: 28129554.0000 - val_mean_absolute_percentage_error: 35.8346
# Epoch 139/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36346112.0000 - mean_absolute_percentage_error: 37.7144 - val_loss: 28112998.0000 - val_mean_absolute_percentage_error: 35.8294
# Epoch 140/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36332264.0000 - mean_absolute_percentage_error: 37.7480 - val_loss: 28108234.0000 - val_mean_absolute_percentage_error: 35.8144
# Epoch 141/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36320848.0000 - mean_absolute_percentage_error: 37.7412 - val_loss: 28090818.0000 - val_mean_absolute_percentage_error: 35.8708
# Epoch 142/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36311744.0000 - mean_absolute_percentage_error: 37.7892 - val_loss: 28076350.0000 - val_mean_absolute_percentage_error: 35.8331
# Epoch 143/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36301792.0000 - mean_absolute_percentage_error: 37.7891 - val_loss: 28062572.0000 - val_mean_absolute_percentage_error: 35.8546
# Epoch 144/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36293144.0000 - mean_absolute_percentage_error: 37.8646 - val_loss: 28057020.0000 - val_mean_absolute_percentage_error: 35.8513
# Epoch 145/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36290344.0000 - mean_absolute_percentage_error: 37.7486 - val_loss: 28048762.0000 - val_mean_absolute_percentage_error: 35.7986
# Epoch 146/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36275836.0000 - mean_absolute_percentage_error: 37.7548 - val_loss: 28034186.0000 - val_mean_absolute_percentage_error: 35.7901
# Epoch 147/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36266676.0000 - mean_absolute_percentage_error: 37.8052 - val_loss: 28016720.0000 - val_mean_absolute_percentage_error: 35.7493
# Epoch 148/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36260952.0000 - mean_absolute_percentage_error: 37.8305 - val_loss: 27999796.0000 - val_mean_absolute_percentage_error: 35.8332
# Epoch 149/150
# 134/134 [==============================] - 0s 1ms/step - loss: 36246832.0000 - mean_absolute_percentage_error: 37.8111 - val_loss: 27993114.0000 - val_mean_absolute_percentage_error: 35.7669
# Epoch 150/150
# 134/134 [==============================] - 0s 2ms/step - loss: 36236044.0000 - mean_absolute_percentage_error: 37.8313 - val_loss: 27986988.0000 - val_mean_absolute_percentage_error: 35.7883

# %% [markdown]
# # Inference

# %% [markdown]
# After training the model, we can use it to predict unknown data.

# %%
predictions = model(test_X_scaled[:10]).numpy()

# %%
predictions
# Out:
# array([[16305.95843232],
#        [ 8903.49716806],
#        [27894.62161983],
#        [ 4704.51260921],
#        [11569.63860048],
#        [10391.21323598],
#        [ 5757.19897229],
#        [ 3306.98482641],
#        [ 3521.82256052],
#        [ 7962.86875142]])
